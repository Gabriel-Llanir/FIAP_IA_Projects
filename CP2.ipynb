# %% [markdown]
# ## Checkpoint 2
#
# Utilizando o código abaixo para gerar dados de duas classes.
#
# implemente uma rede neural que seja capaz de classificar corretamente os dados.
#
# Utilize como parâmetros seu proprio RM.
#
# exemplo:
#  RM = abcde
#  - nData = 100 * (a+b+c+d+e)
#  - nVertices = 1 * maximo(a,b,c,d,e)

# %%
  ### execute essa celula, mas não altere essa função.

import numpy as np
import matplotlib.pyplot as plt

  def generate_data(nData, nVertices):
    c = np.random.uniform()*2*np.pi
    c1 = np.zeros((nData,2))
    c2 = np.zeros((nData,2))
    for ii in range(nData):
      th = np.random.uniform()*2*np.pi;
      r  = 0.5*np.random.uniform()+1.25+0.2*np.cos(nVertices*(th+c));
      c1[ii,:]=r*np.array([np.cos(th), np.sin(th)]);

      th = np.random.uniform()*3*np.pi;
      r  = np.random.uniform()+0.3*np.cos(nVertices*(th+c));
      c2[ii,:]=r*np.array([np.cos(th), np.sin(th)]);
    return c1, c2

# %%
## coloque seu RM aqui!!
RM = [9,4,5,9,8]

nData = 100 * (sum(RM))
nVertices = 1 * max(RM)

#gera os dados
c1, c2 = generate_data(nData,nVertices)

#plot dos dados
plt.scatter(c1[:,0],c1[:,1])
plt.scatter(c2[:,0],c2[:,1])

# %% [markdown]
# Comente sobre a decisão de cada parametro utilizado:
#
# Serão avaliados:
#     - estrutura do código
#     - testes realizados
#     - Números de neurônios
#     - Número de camadas
#     - Algoritmo de adaptação
#     - Partâmetros do algoritmo de adaptação
#     - Função de ativação

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization

def create_model(dataset):
    model = Sequential()
    model.add(Dense(units=100, input_shape=([1]), activation='relu'))
    model.add(BatchNormalization())
 
    if dataset == 'rodada2': model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    else: model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return model

print(RM)
model = create_model(RM)

model.summary()
print("Loss function:", model.loss)
print("Optimizer name:", model.optimizer.get_config()["name"])
# Out:
# [9, 4, 5, 9, 8]
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 100)               200
#
#  batch_normalization_3 (Batc  (None, 100)              400
#  hNormalization)
#
# =================================================================
# Total params: 600
# Trainable params: 400
# Non-trainable params: 200
# _________________________________________________________________
# Loss function: sparse_categorical_crossentropy
# Optimizer name: Adam

# %%
history = model.fit(c1, c2, epochs=10, validation_split=0.2)

train_loss, train_acc = model.evaluate(c1,  c2, verbose=2)
test_loss, test_acc = model.evaluate(c1,  c2, verbose=2)
